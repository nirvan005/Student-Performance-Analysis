# %%
def apply_log1p(x):
    return np.log1p(x.astype(float))

# %%
pipe=pickle.load(open('PerformancePrediction.pkl','rb'))

# %%
student1=np.array(['GP', 'M', 15, 'U', 'GT3', 'T', 4, 4, 'services', 'teacher',
        'course', 'father', 1, 2, 0, 'no', 'yes', 'no', 'yes', 'yes',
        'yes', 'yes', 'no', 4, 3, 3, 1, 1, 5, 2, 19, 18])

# %%
pipe.predict([student1]) #actual value 18
# Out:
# C:\Users\nirva\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# array([18.75548752])
